# %%
import pandas as pd

# Sample data you provided
data = [
    ["2025-07-04", 107984.24],
    ["2025-07-05", 108198.12, 0.2],
    ["2025-07-06", 109203.84, 0.93],
    ["2025-07-07", 108262.94, -0.86],
    ["2025-07-08", 108922.98, 0.61, 3.07],
    ["2025-07-09", 111233.99, 2.12, 2.19],
    ["2025-07-10", 116010, 4.29, 5.86],
    ["2025-07-11", 117527.66, 1.31, 8.84],
    ["2025-07-12", 117420, -0.09, 8.52],
    ["2025-07-13", 119086.64, 1.42, 9.05],
    ["2025-07-14", 20354.94, 1.07, 11.17],
    ["2025-07-15", 120354.94, 1.07, 10.55],
    ["2025-07-15", 116383.33, 0, 0],
    ["2025-07-15", 116371.66, 0, 0],
]

# Create DataFrame and ensure the column names are correct
df = pd.DataFrame(data, columns=["date", "price", "change_24h", "change_7d"])

# Convert 'date' column to datetime
df["date"] = pd.to_datetime(df["date"])

# Drop duplicates for the same day and take the last entry for each day
df = df.groupby("date").last().reset_index()

# Print DataFrame to verify it's correct
print("Data after removing duplicates and resetting index:")
print(df)

# Check if 'price' column is missing
if 'price' not in df.columns:
    print("❌ 'price' column is missing in the DataFrame!")
else:
    print("✅ 'price' column found!")

# Calculate 24h change and 7d change based on the available data
df["change_24h"] = df["price"].pct_change() * 100
df["change_7d"] = df["price"].pct_change(periods=7) * 100

print("DataFrame after calculating changes:")
print(df)

# Checking if the changes are calculated correctly
print(df.tail())
# Out:
# Data after removing duplicates and resetting index:
#          date      price  change_24h  change_7d
# 0  2025-07-04  107984.24         NaN        NaN
# 1  2025-07-05  108198.12        0.20        NaN
# 2  2025-07-06  109203.84        0.93        NaN
# 3  2025-07-07  108262.94       -0.86        NaN
# 4  2025-07-08  108922.98        0.61       3.07
# 5  2025-07-09  111233.99        2.12       2.19
# 6  2025-07-10  116010.00        4.29       5.86
# 7  2025-07-11  117527.66        1.31       8.84
# 8  2025-07-12  117420.00       -0.09       8.52
# 9  2025-07-13  119086.64        1.42       9.05
# 10 2025-07-14   20354.94        1.07      11.17
# 11 2025-07-15  116371.66        0.00       0.00
# ✅ 'price' column found!
# DataFrame after calculating changes:
#          date      price  change_24h  change_7d
# 0  2025-07-04  107984.24         NaN        NaN
# 1  2025-07-05  108198.12    0.198066        NaN
# 2  2025-07-06  109203.84    0.929517        NaN
# ...

# %%
# Handling missing values by forward filling (or you could use other strategies like filling with 0)
df['change_24h'] = df['change_24h'].fillna(0)
df['change_7d'] = df['change_7d'].fillna(0)

# Handling extreme outliers: for example, removing rows where the change exceeds 100% (you can adjust this threshold)
df = df[(df['change_24h'] < 100) & (df['change_24h'] > -100)]  # Adjust the range if necessary

# Proceed with your feature engineering and model training
df = label_trend(df)
df = create_features(df)

# Now proceed with the ML pipeline
st.info(f"🧮 Rows after feature engineering: {len(df)}")

try:
    model = train_trend_model(df)
except Exception as e:
    st.error(f"❌ Model training error: {e}")
    st.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6 df = df[(df['change_24h'] < 100) & (df['change_24h'] > -100)]  # Adjust the range if necessary
#       8 # Proceed with your feature engineering and model training
# ----> 9 df = label_trend(df)
#      10 df = create_features(df)
#      12 # Now proceed with the ML pipeline
#
# NameError: name 'label_trend' is not defined

# %%
import pandas as pd

# Sample data you provided
data = [
    ["2025-07-04", 107984.24],
    ["2025-07-05", 108198.12, 0.2],
    ["2025-07-06", 109203.84, 0.93],
    ["2025-07-07", 108262.94, -0.86],
    ["2025-07-08", 108922.98, 0.61, 3.07],
    ["2025-07-09", 111233.99, 2.12, 2.19],
    ["2025-07-10", 116010, 4.29, 5.86],
    ["2025-07-11", 117527.66, 1.31, 8.84],
    ["2025-07-12", 117420, -0.09, 8.52],
    ["2025-07-13", 119086.64, 1.42, 9.05],
    ["2025-07-14", 20354.94, 1.07, 11.17],
    ["2025-07-15", 120354.94, 1.07, 10.55],
    ["2025-07-15", 116383.33, 0, 0],
    ["2025-07-15", 116371.66, 0, 0],
]

# Create DataFrame
df = pd.DataFrame(data, columns=["date", "price", "change_24h", "change_7d"])

# Convert 'date' column to datetime
df["date"] = pd.to_datetime(df["date"])

# Remove duplicates and keep the first occurrence
df = df.drop_duplicates(subset='date', keep='first')

# Display cleaned data
df
# Out:
#          date      price  change_24h  change_7d
# 0  2025-07-04  107984.24         NaN        NaN
# 1  2025-07-05  108198.12        0.20        NaN
# 2  2025-07-06  109203.84        0.93        NaN
# 3  2025-07-07  108262.94       -0.86        NaN
# 4  2025-07-08  108922.98        0.61       3.07
# 5  2025-07-09  111233.99        2.12       2.19
# 6  2025-07-10  116010.00        4.29       5.86
# 7  2025-07-11  117527.66        1.31       8.84
# 8  2025-07-12  117420.00       -0.09       8.52
# 9  2025-07-13  119086.64        1.42       9.05
# 10 2025-07-14   20354.94        1.07      11.17
# 11 2025-07-15  120354.94        1.07      10.55

# %%
# After you have cleaned and processed the data in the DataFrame (df)

import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Authenticate with Google Sheets
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("credentials.json", scope)
client = gspread.authorize(creds)

# Open your Google Sheet by name and select the worksheet
sheet = client.open("btc_price_log").worksheet("DailyPrice")

# Clear existing data in the sheet (optional, if you want to overwrite everything)
sheet.clear()

# Write the cleaned data to the sheet
sheet.update([df.columns.values.tolist()] + df.values.tolist())

# Confirm that data was uploaded
print("Data successfully updated to Google Sheet!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 18
#      15 sheet.clear()
#      17 # Write the cleaned data to the sheet
# ---> 18 sheet.update([df.columns.values.tolist()] + df.values.tolist())
#      20 # Confirm that data was uploaded
#      21 print("Data successfully updated to Google Sheet!")
#
# File /opt/anaconda3/lib/python3.12/site-packages/gspread/worksheet.py:1246, in Worksheet.update(self, values, range_name, raw, major_dimension, value_input_option, include_values_in_response, response_value_render_option, response_date_time_render_option)
#    1235     value_input_option = (
#    1236         ValueInputOption.raw if raw is True else ValueInputOption.user_entered
#    1237     )
#    1239 params: ParamsType = {
#    1240     "valueInputOption": value_input_option,
#    1241     "includeValuesInResponse": include_values_in_response,
# ...

# %%
import streamlit as st
import json

# Get credentials from Streamlit secrets (if using Streamlit secrets)
credentials_json = st.secrets["google_credentials"]["value"]

# If you're testing locally and using a credentials file directly, comment out the line above:
# credentials_json = open("path/to/your/credentials.json").read()

print(credentials_json)
# Out:
# {
#   "type": "service_account",
#   "project_id": "btc-logger-app",
#   "private_key_id": "7f07a07d228e649082e5bf350add2b0985b62b31",
# ...
